# %% [markdown]
# # Environment Configuration Instructions

# %% [markdown]
# 1. Create a .venv environment
# 2. Install the base requirements by running `pip install -r requirements.txt`
# 3. Run the following cell and write down your **CUDA Version**

# %%
# !nvidia-smi
# Out:
# Sat Aug  1 12:12:06 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.173.02             Driver Version: 580.173.02     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA TITAN X (Pascal)        On  |   00000000:01:00.0  On |                  N/A |
# | 36%   63C    P2             65W /  250W |     618MiB /  12288MiB |      3%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            3037      G   /usr/lib/xorg/Xorg                      141MiB |
# |    0   N/A  N/A            3285      G   /usr/bin/gnome-shell                     48MiB |
# |    0   N/A  N/A         1127215      C   /usr/share/rustdesk/rustdesk            165MiB |
# |    0   N/A  N/A         1136917      G   /usr/share/rustdesk/rustdesk             12MiB |
# |    0   N/A  N/A         1140823      G   /usr/share/code/code                    100MiB |
# |    0   N/A  N/A         1149900      G   .../8633/usr/lib/firefox/firefox        135MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# 4. Go to [Pytorch](https://pytorch.org/get-started/locally/) and copy and run the install command that matches the properties of your machine and your **CUDA Version**
# 5. Only **AFTER** Pytorch has been installed, you can install ultralytics by running the pip command posted on their [webpage](https://docs.ultralytics.com/quickstart)

# %% [markdown]
# # Environment Check

# %%
import torch
import ultralytics

print("Ultralytics version:", ultralytics.__version__)
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Ultralytics version: 8.4.115
# PyTorch version: 2.13.0+cu130
# CUDA available: True
# GPU: NVIDIA TITAN X (Pascal)

# %% [markdown]
# # Roboflow API Setup and Dataset Retrieval

# %%
from roboflow import Roboflow
from pathlib import Path
import shutil

# Roboflow has problems downloading to an existing directory, so we assure that it does not exists
data_folder = Path("../data")
if data_folder.exists():
    shutil.rmtree(data_folder)

rf = Roboflow(api_key="iSUpQqSxeaupKuugZKmc")
project = rf.workspace("metis-bwgip").project("metis_detection_solo_botellas")
version = project.version(1)
dataset = version.download(model_format="yolo26", location="../data")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in ../data to yolo26:: 100%|██████████| 122754/122754 [00:11<00:00, 10583.89it/s]
# Extracting Dataset Version Zip to ../data in yolo26:: 100%|██████████| 2409/2409 [00:00<00:00, 5998.46it/s]

# %% [markdown]
# # Training

# %%
from ultralytics import YOLO
model_x = YOLO("../models/yolo26x.pt",verbose=False)
del model_x
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26x.pt to '../models/yolo26x.pt': 100% ━━━━━━━━━━━━ 113.2MB 10.1MB/s 11.2s1.2s<0.0ss

# %%
# !python ../scripts/training.py
# Out:
# Ultralytics 8.4.115 🚀 Python-3.10.12 torch-2.13.0+cu126 CUDA:0 (NVIDIA TITAN X (Pascal), 12182MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.5, data=/home/pcvision/KYMA/METIS/proj-metis/data/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=10, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.5, mode=train, model=/home/pcvision/KYMA/METIS/proj-metis/models/yolo26x.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=v1-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=training_results, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/pcvision/KYMA/METIS/proj-metis/notebooks/runs/detect/training_results/v1-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5, 3, True]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   4436736  ultralytics.nn.modules.block.C3k2            [1536, 768, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   6260772  ultralytics.nn.modules.head.Detect           [2, 1, True, [384, 768, 768]]
# YOLO26x summary: 392 layers, 58,813,188 parameters, 58,813,188 gradients, 209.1 GFLOPs
#
# Transferred 1080/1092 items from pretrained weights
# Freezing layer 'model.0.conv.weight'
# Freezing layer 'model.0.bn.weight'
# Freezing layer 'model.0.bn.bias'
# Freezing layer 'model.1.conv.weight'
# Freezing layer 'model.1.bn.weight'
# Freezing layer 'model.1.bn.bias'
# Freezing layer 'model.2.cv1.conv.weight'
# Freezing layer 'model.2.cv1.bn.weight'
# Freezing layer 'model.2.cv1.bn.bias'
# Freezing layer 'model.2.cv2.conv.weight'
# Freezing layer 'model.2.cv2.bn.weight'
# Freezing layer 'model.2.cv2.bn.bias'
# Freezing layer 'model.2.m.0.cv1.conv.weight'
# Freezing layer 'model.2.m.0.cv1.bn.weight'
# Freezing layer 'model.2.m.0.cv1.bn.bias'
# Freezing layer 'model.2.m.0.cv2.conv.weight'
# Freezing layer 'model.2.m.0.cv2.bn.weight'
# Freezing layer 'model.2.m.0.cv2.bn.bias'
# Freezing layer 'model.2.m.0.cv3.conv.weight'
# Freezing layer 'model.2.m.0.cv3.bn.weight'
# Freezing layer 'model.2.m.0.cv3.bn.bias'
# Freezing layer 'model.2.m.0.m.0.cv1.conv.weight'
# Freezing layer 'model.2.m.0.m.0.cv1.bn.weight'
# Freezing layer 'model.2.m.0.m.0.cv1.bn.bias'
# Freezing layer 'model.2.m.0.m.0.cv2.conv.weight'
# Freezing layer 'model.2.m.0.m.0.cv2.bn.weight'
# Freezing layer 'model.2.m.0.m.0.cv2.bn.bias'
# Freezing layer 'model.2.m.0.m.1.cv1.conv.weight'
# Freezing layer 'model.2.m.0.m.1.cv1.bn.weight'
# Freezing layer 'model.2.m.0.m.1.cv1.bn.bias'
# Freezing layer 'model.2.m.0.m.1.cv2.conv.weight'
# Freezing layer 'model.2.m.0.m.1.cv2.bn.weight'
# Freezing layer 'model.2.m.0.m.1.cv2.bn.bias'
# Freezing layer 'model.2.m.1.cv1.conv.weight'
# Freezing layer 'model.2.m.1.cv1.bn.weight'
# Freezing layer 'model.2.m.1.cv1.bn.bias'
# Freezing layer 'model.2.m.1.cv2.conv.weight'
# Freezing layer 'model.2.m.1.cv2.bn.weight'
# Freezing layer 'model.2.m.1.cv2.bn.bias'
# Freezing layer 'model.2.m.1.cv3.conv.weight'
# Freezing layer 'model.2.m.1.cv3.bn.weight'
# Freezing layer 'model.2.m.1.cv3.bn.bias'
# Freezing layer 'model.2.m.1.m.0.cv1.conv.weight'
# Freezing layer 'model.2.m.1.m.0.cv1.bn.weight'
# Freezing layer 'model.2.m.1.m.0.cv1.bn.bias'
# Freezing layer 'model.2.m.1.m.0.cv2.conv.weight'
# Freezing layer 'model.2.m.1.m.0.cv2.bn.weight'
# Freezing layer 'model.2.m.1.m.0.cv2.bn.bias'
# Freezing layer 'model.2.m.1.m.1.cv1.conv.weight'
# Freezing layer 'model.2.m.1.m.1.cv1.bn.weight'
# Freezing layer 'model.2.m.1.m.1.cv1.bn.bias'
# Freezing layer 'model.2.m.1.m.1.cv2.conv.weight'
# Freezing layer 'model.2.m.1.m.1.cv2.bn.weight'
# Freezing layer 'model.2.m.1.m.1.cv2.bn.bias'
# Freezing layer 'model.3.conv.weight'
# Freezing layer 'model.3.bn.weight'
# Freezing layer 'model.3.bn.bias'
# Freezing layer 'model.4.cv1.conv.weight'
# Freezing layer 'model.4.cv1.bn.weight'
# Freezing layer 'model.4.cv1.bn.bias'
# Freezing layer 'model.4.cv2.conv.weight'
# Freezing layer 'model.4.cv2.bn.weight'
# Freezing layer 'model.4.cv2.bn.bias'
# Freezing layer 'model.4.m.0.cv1.conv.weight'
# Freezing layer 'model.4.m.0.cv1.bn.weight'
# Freezing layer 'model.4.m.0.cv1.bn.bias'
# Freezing layer 'model.4.m.0.cv2.conv.weight'
# Freezing layer 'model.4.m.0.cv2.bn.weight'
# Freezing layer 'model.4.m.0.cv2.bn.bias'
# Freezing layer 'model.4.m.0.cv3.conv.weight'
# Freezing layer 'model.4.m.0.cv3.bn.weight'
# Freezing layer 'model.4.m.0.cv3.bn.bias'
# Freezing layer 'model.4.m.0.m.0.cv1.conv.weight'
# Freezing layer 'model.4.m.0.m.0.cv1.bn.weight'
# Freezing layer 'model.4.m.0.m.0.cv1.bn.bias'
# Freezing layer 'model.4.m.0.m.0.cv2.conv.weight'
# Freezing layer 'model.4.m.0.m.0.cv2.bn.weight'
# Freezing layer 'model.4.m.0.m.0.cv2.bn.bias'
# Freezing layer 'model.4.m.0.m.1.cv1.conv.weight'
# Freezing layer 'model.4.m.0.m.1.cv1.bn.weight'
# Freezing layer 'model.4.m.0.m.1.cv1.bn.bias'
# Freezing layer 'model.4.m.0.m.1.cv2.conv.weight'
# Freezing layer 'model.4.m.0.m.1.cv2.bn.weight'
# Freezing layer 'model.4.m.0.m.1.cv2.bn.bias'
# Freezing layer 'model.4.m.1.cv1.conv.weight'
# Freezing layer 'model.4.m.1.cv1.bn.weight'
# Freezing layer 'model.4.m.1.cv1.bn.bias'
# Freezing layer 'model.4.m.1.cv2.conv.weight'
# Freezing layer 'model.4.m.1.cv2.bn.weight'
# Freezing layer 'model.4.m.1.cv2.bn.bias'
# Freezing layer 'model.4.m.1.cv3.conv.weight'
# Freezing layer 'model.4.m.1.cv3.bn.weight'
# Freezing layer 'model.4.m.1.cv3.bn.bias'
# Freezing layer 'model.4.m.1.m.0.cv1.conv.weight'
# Freezing layer 'model.4.m.1.m.0.cv1.bn.weight'
# Freezing layer 'model.4.m.1.m.0.cv1.bn.bias'
# Freezing layer 'model.4.m.1.m.0.cv2.conv.weight'
# Freezing layer 'model.4.m.1.m.0.cv2.bn.weight'
# Freezing layer 'model.4.m.1.m.0.cv2.bn.bias'
# Freezing layer 'model.4.m.1.m.1.cv1.conv.weight'
# Freezing layer 'model.4.m.1.m.1.cv1.bn.weight'
# Freezing layer 'model.4.m.1.m.1.cv1.bn.bias'
# Freezing layer 'model.4.m.1.m.1.cv2.conv.weight'
# Freezing layer 'model.4.m.1.m.1.cv2.bn.weight'
# Freezing layer 'model.4.m.1.m.1.cv2.bn.bias'
# Freezing layer 'model.5.conv.weight'
# Freezing layer 'model.5.bn.weight'
# Freezing layer 'model.5.bn.bias'
# Freezing layer 'model.6.cv1.conv.weight'
# Freezing layer 'model.6.cv1.bn.weight'
# Freezing layer 'model.6.cv1.bn.bias'
# Freezing layer 'model.6.cv2.conv.weight'
# Freezing layer 'model.6.cv2.bn.weight'
# Freezing layer 'model.6.cv2.bn.bias'
# Freezing layer 'model.6.m.0.cv1.conv.weight'
# Freezing layer 'model.6.m.0.cv1.bn.weight'
# Freezing layer 'model.6.m.0.cv1.bn.bias'
# Freezing layer 'model.6.m.0.cv2.conv.weight'
# Freezing layer 'model.6.m.0.cv2.bn.weight'
# Freezing layer 'model.6.m.0.cv2.bn.bias'
# Freezing layer 'model.6.m.0.cv3.conv.weight'
# Freezing layer 'model.6.m.0.cv3.bn.weight'
# Freezing layer 'model.6.m.0.cv3.bn.bias'
# Freezing layer 'model.6.m.0.m.0.cv1.conv.weight'
# Freezing layer 'model.6.m.0.m.0.cv1.bn.weight'
# Freezing layer 'model.6.m.0.m.0.cv1.bn.bias'
# Freezing layer 'model.6.m.0.m.0.cv2.conv.weight'
# Freezing layer 'model.6.m.0.m.0.cv2.bn.weight'
# Freezing layer 'model.6.m.0.m.0.cv2.bn.bias'
# Freezing layer 'model.6.m.0.m.1.cv1.conv.weight'
# Freezing layer 'model.6.m.0.m.1.cv1.bn.weight'
# Freezing layer 'model.6.m.0.m.1.cv1.bn.bias'
# Freezing layer 'model.6.m.0.m.1.cv2.conv.weight'
# Freezing layer 'model.6.m.0.m.1.cv2.bn.weight'
# Freezing layer 'model.6.m.0.m.1.cv2.bn.bias'
# Freezing layer 'model.6.m.1.cv1.conv.weight'
# Freezing layer 'model.6.m.1.cv1.bn.weight'
# Freezing layer 'model.6.m.1.cv1.bn.bias'
# Freezing layer 'model.6.m.1.cv2.conv.weight'
# Freezing layer 'model.6.m.1.cv2.bn.weight'
# Freezing layer 'model.6.m.1.cv2.bn.bias'
# Freezing layer 'model.6.m.1.cv3.conv.weight'
# Freezing layer 'model.6.m.1.cv3.bn.weight'
# Freezing layer 'model.6.m.1.cv3.bn.bias'
# Freezing layer 'model.6.m.1.m.0.cv1.conv.weight'
# Freezing layer 'model.6.m.1.m.0.cv1.bn.weight'
# Freezing layer 'model.6.m.1.m.0.cv1.bn.bias'
# Freezing layer 'model.6.m.1.m.0.cv2.conv.weight'
# Freezing layer 'model.6.m.1.m.0.cv2.bn.weight'
# Freezing layer 'model.6.m.1.m.0.cv2.bn.bias'
# Freezing layer 'model.6.m.1.m.1.cv1.conv.weight'
# Freezing layer 'model.6.m.1.m.1.cv1.bn.weight'
# Freezing layer 'model.6.m.1.m.1.cv1.bn.bias'
# Freezing layer 'model.6.m.1.m.1.cv2.conv.weight'
# Freezing layer 'model.6.m.1.m.1.cv2.bn.weight'
# Freezing layer 'model.6.m.1.m.1.cv2.bn.bias'
# Freezing layer 'model.7.conv.weight'
# Freezing layer 'model.7.bn.weight'
# Freezing layer 'model.7.bn.bias'
# Freezing layer 'model.8.cv1.conv.weight'
# Freezing layer 'model.8.cv1.bn.weight'
# Freezing layer 'model.8.cv1.bn.bias'
# Freezing layer 'model.8.cv2.conv.weight'
# Freezing layer 'model.8.cv2.bn.weight'
# Freezing layer 'model.8.cv2.bn.bias'
# Freezing layer 'model.8.m.0.cv1.conv.weight'
# Freezing layer 'model.8.m.0.cv1.bn.weight'
# Freezing layer 'model.8.m.0.cv1.bn.bias'
# Freezing layer 'model.8.m.0.cv2.conv.weight'
# Freezing layer 'model.8.m.0.cv2.bn.weight'
# Freezing layer 'model.8.m.0.cv2.bn.bias'
# Freezing layer 'model.8.m.0.cv3.conv.weight'
# Freezing layer 'model.8.m.0.cv3.bn.weight'
# Freezing layer 'model.8.m.0.cv3.bn.bias'
# Freezing layer 'model.8.m.0.m.0.cv1.conv.weight'
# Freezing layer 'model.8.m.0.m.0.cv1.bn.weight'
# Freezing layer 'model.8.m.0.m.0.cv1.bn.bias'
# Freezing layer 'model.8.m.0.m.0.cv2.conv.weight'
# Freezing layer 'model.8.m.0.m.0.cv2.bn.weight'
# Freezing layer 'model.8.m.0.m.0.cv2.bn.bias'
# Freezing layer 'model.8.m.0.m.1.cv1.conv.weight'
# Freezing layer 'model.8.m.0.m.1.cv1.bn.weight'
# Freezing layer 'model.8.m.0.m.1.cv1.bn.bias'
# Freezing layer 'model.8.m.0.m.1.cv2.conv.weight'
# Freezing layer 'model.8.m.0.m.1.cv2.bn.weight'
# Freezing layer 'model.8.m.0.m.1.cv2.bn.bias'
# Freezing layer 'model.8.m.1.cv1.conv.weight'
# Freezing layer 'model.8.m.1.cv1.bn.weight'
# Freezing layer 'model.8.m.1.cv1.bn.bias'
# Freezing layer 'model.8.m.1.cv2.conv.weight'
# Freezing layer 'model.8.m.1.cv2.bn.weight'
# Freezing layer 'model.8.m.1.cv2.bn.bias'
# Freezing layer 'model.8.m.1.cv3.conv.weight'
# Freezing layer 'model.8.m.1.cv3.bn.weight'
# Freezing layer 'model.8.m.1.cv3.bn.bias'
# Freezing layer 'model.8.m.1.m.0.cv1.conv.weight'
# Freezing layer 'model.8.m.1.m.0.cv1.bn.weight'
# Freezing layer 'model.8.m.1.m.0.cv1.bn.bias'
# Freezing layer 'model.8.m.1.m.0.cv2.conv.weight'
# Freezing layer 'model.8.m.1.m.0.cv2.bn.weight'
# Freezing layer 'model.8.m.1.m.0.cv2.bn.bias'
# Freezing layer 'model.8.m.1.m.1.cv1.conv.weight'
# Freezing layer 'model.8.m.1.m.1.cv1.bn.weight'
# Freezing layer 'model.8.m.1.m.1.cv1.bn.bias'
# Freezing layer 'model.8.m.1.m.1.cv2.conv.weight'
# Freezing layer 'model.8.m.1.m.1.cv2.bn.weight'
# Freezing layer 'model.8.m.1.m.1.cv2.bn.bias'
# Freezing layer 'model.9.cv1.conv.weight'
# Freezing layer 'model.9.cv1.bn.weight'
# Freezing layer 'model.9.cv1.bn.bias'
# Freezing layer 'model.9.cv2.conv.weight'
# Freezing layer 'model.9.cv2.bn.weight'
# Freezing layer 'model.9.cv2.bn.bias'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 10.7MB/s 0.5s.4s<0.1s.5s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3306.3±799.2 MB/s, size: 98.8 KB)
# train: Scanning /home/pcvision/KYMA/METIS/proj-metis/data/train/labels... 859 images, 53 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 859/859 1.1Kit/s 0.7s0.1ss
# train: New cache created: /home/pcvision/KYMA/METIS/proj-metis/data/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 8561, len(boxes) = 8736. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1774.1±1253.6 MB/s, size: 98.0 KB)
# val: Scanning /home/pcvision/KYMA/METIS/proj-metis/data/valid/labels... 226 images, 18 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 226/226 426.8it/s 0.5s0.1s
# val: New cache created: /home/pcvision/KYMA/METIS/proj-metis/data/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2540, len(boxes) = 2581. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 178 weight(decay=0.0), 190 weight(decay=0.0005), 190 bias(decay=0.0)
# Plotting labels to /home/pcvision/KYMA/METIS/proj-metis/notebooks/runs/detect/training_results/v1-2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/pcvision/KYMA/METIS/proj-metis/notebooks/runs/detect/training_results/v1-2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       1/100      8.43G      1.214      1.876   0.004772        426        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.4sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.4s/it 11.2s1.6s
#                    all        226       2581      0.938      0.418      0.449      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       2/100       8.7G      1.247      1.007   0.005235        259        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:211.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.5s1.6s
#                    all        226       2581      0.927      0.413      0.517       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       3/100      8.57G      1.251     0.8652   0.005002        171        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:211.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.4s/it 11.2s1.7s
#                    all        226       2581      0.599      0.688      0.661      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       4/100      8.43G      1.284     0.8575   0.005633        144        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:221.4sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.4s/it 11.1s1.7s
#                    all        226       2581      0.775      0.646      0.734       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       5/100      8.79G      1.216     0.7783   0.005172        303        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:221.4sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.8s1.7s
#                    all        226       2581      0.875      0.709      0.797      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       6/100      8.54G      1.194     0.7242   0.004944        256        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:211.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.7s1.6s
#                    all        226       2581      0.834      0.792      0.814       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       7/100      8.42G      1.214      0.737   0.005132        188        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:201.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.7s1.6s
#                    all        226       2581      0.851      0.725      0.781      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       8/100      8.73G      1.169     0.7129   0.004702        184        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:201.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.7s1.6s
#                    all        226       2581      0.827      0.812      0.833      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       9/100      8.58G      1.143      0.723   0.004823        188        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:201.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.7s1.6s
#                    all        226       2581      0.858      0.691      0.792      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      10/100      8.76G      1.132      0.715   0.004836        252        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:201.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.7s1.6s
#                    all        226       2581      0.857      0.819      0.832      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      11/100      8.53G      1.115     0.6684   0.004724        264        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:201.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.7s1.6s
#                    all        226       2581      0.819      0.815      0.847      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      12/100      8.56G       1.09     0.6545   0.004845        319        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:201.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.7s1.6s
#                    all        226       2581      0.845      0.787      0.839      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      13/100      8.63G      1.119     0.6349   0.004487        170        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:201.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.7s1.6s
#                    all        226       2581      0.916      0.808      0.849       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      14/100      8.43G      1.089     0.6371   0.004525        294        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:201.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.7s1.6s
#                    all        226       2581      0.855      0.846      0.862      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      15/100      8.48G      1.117      0.636   0.004403        273        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:201.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.7s1.6s
#                    all        226       2581      0.884      0.834      0.863      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      16/100      8.68G      1.091     0.6258   0.004263        310        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:201.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.7s1.6s
#                    all        226       2581      0.846      0.814       0.85      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      17/100      8.39G       1.06     0.6353   0.004411        300        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:201.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10
0.725
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      81/100      8.63G     0.8276     0.4348   0.003145        250        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:191.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.1s.5ss
#                    all        226       2581      0.917      0.837      0.879      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      82/100       8.5G     0.8076     0.4224   0.003094        127        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.6s1.6s
#                    all        226       2581      0.935      0.812      0.875      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      83/100      8.51G     0.8029     0.4181    0.00306        161        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.3s1.6s
#                    all        226       2581      0.919      0.823      0.874      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      84/100       8.6G     0.7848     0.4265   0.003051        301        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.3s1.6s
#                    all        226       2581      0.939      0.817      0.877      0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      85/100      8.47G     0.7919     0.4163   0.003086        264        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.4s1.6s
#                    all        226       2581       0.92      0.854      0.883      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      86/100      8.53G     0.7986     0.4172   0.002969        172        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.5s1.6s
#                    all        226       2581      0.918      0.814      0.872      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      87/100      8.48G     0.7788     0.4223   0.003122        341        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.5s1.6s
#                    all        226       2581      0.938      0.798      0.873      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      88/100      8.69G     0.7975     0.4201   0.003099        205        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.4s1.6s
#                    all        226       2581      0.904      0.832      0.882      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      89/100      8.78G     0.7973     0.4238   0.003086        226        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.3s1.6s
#                    all        226       2581      0.904      0.855      0.884      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      90/100      8.42G     0.7814     0.4156    0.00306        281        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.4s1.6s
#                    all        226       2581      0.909      0.824      0.889      0.724
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      91/100      8.44G      0.546     0.2518   0.002528         77        640: 100% ━━━━━━━━━━━━ 54/54 1.5s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.4s1.6s
#                    all        226       2581      0.898      0.857      0.889      0.725
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      92/100      8.39G     0.5355     0.2483   0.002275        106        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.4s1.6s
#                    all        226       2581      0.913      0.847      0.889      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      93/100      8.38G     0.5429     0.2467   0.002292        117        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.4s1.6s
#                    all        226       2581      0.908      0.856      0.888      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      94/100      8.36G     0.5241     0.2385   0.002162         92        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.4s1.6s
#                    all        226       2581      0.912       0.85      0.888      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      95/100      8.44G      0.535     0.2449   0.002285         96        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.3s1.6s
#                    all        226       2581      0.906      0.858      0.888      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      96/100      8.44G     0.5253     0.2365   0.002234         88        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.3s1.6s
#                    all        226       2581      0.907      0.851      0.887      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      97/100      8.46G     0.5377     0.2406   0.002276         81        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.4s1.6s
#                    all        226       2581      0.906      0.858      0.886      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      98/100      8.34G     0.5261     0.2378   0.002292        112        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.3s1.6s
#                    all        226       2581      0.913      0.872      0.888      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      99/100      8.37G     0.5189     0.2288   0.002134        214        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.5s1.6s
#                    all        226       2581      0.905       0.86      0.887      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#     100/100      8.43G     0.5336     0.2381   0.002233        142        640: 100% ━━━━━━━━━━━━ 54/54 1.4s/it 1:181.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.5s1.6s
#                    all        226       2581      0.906      0.865      0.888      0.731
#
# 100 epochs completed in 2.525 hours.
# Optimizer stripped from /home/pcvision/KYMA/METIS/proj-metis/notebooks/runs/detect/training_results/v1-2/weights/last.pt, 118.3MB
# Optimizer stripped from /home/pcvision/KYMA/METIS/proj-metis/notebooks/runs/detect/training_results/v1-2/weights/best.pt, 118.3MB
#
# Validating /home/pcvision/KYMA/METIS/proj-metis/notebooks/runs/detect/training_results/v1-2/weights/best.pt...
# Ultralytics 8.4.115 🚀 Python-3.10.12 torch-2.13.0+cu126 CUDA:0 (NVIDIA TITAN X (Pascal), 12182MiB)
# YOLO26x summary (fused): 190 layers, 55,635,858 parameters, 0 gradients, 193.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.3s/it 10.1s1.5s
#                    all        226       2581      0.922       0.85      0.892      0.731
#         Plastic_Bottle        207       2517       0.92      0.938      0.947      0.811
#   Plastico_un_solo_uso         27         64      0.924      0.761      0.836      0.652
# Speed: 0.2ms preprocess, 40.5ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to /home/pcvision/KYMA/METIS/proj-metis/notebooks/runs/detect/training_results/v1-2
